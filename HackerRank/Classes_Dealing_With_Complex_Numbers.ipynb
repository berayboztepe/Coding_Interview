# %% [markdown]
# ![4.PNG](attachment:4.PNG)

# %% [markdown]
# ![resim_2021-04-05_205316.png](attachment:resim_2021-04-05_205316.png)

# %%
import math

class Complex(object):
    def __init__(self, real, imaginary):
        self.real, self.imaginary = real, imaginary
        
    def __add__(self, no):
        if self.imaginary > 0:
            return "%.2f+%.2fi" % (self.real + no.real, self.imaginary + no.imaginary)
        else:
            return "%.2f-%.2fi" % (self.real + no.real, abs(self.imaginary + no.imaginary))
    def __sub__(self, no):
        if self.imaginary - no.imaginary < 0: return "%.2f""%.2fi" % (self.real - no.real, self.imaginary - no.imaginary)
        else: return "%.2f+%.2fi" % (self.real - no.real, self.imaginary - no.imaginary)
    def __mul__(self, no):
        if ((self.imaginary * no.real) + (self.real * no.imaginary)) < 0: return "%.2f""%.2fi" % ((self.real * no.real + (-1 * self.imaginary * no.imaginary)), (self.imaginary * no.real) + (self.real * no.imaginary))
        else: return "%.2f+%.2fi" % ((self.real * no.real + (-1 * self.imaginary * no.imaginary)), (self.imaginary * no.real) + (self.real * no.imaginary))
    def __truediv__(self, no):
        result = complex(self.real, self.imaginary) / complex(no.real, no.imaginary)
        if result.imag < 0:
            return "%.2f" % result.real + "%.2fi" % result.imag
        else: return "%.2f" % result.real + "+%.2fi" % (result.imag+0)
    def mod(self):
        return "%.2f+0.00i" % (((self.real ** 2) + (self.imaginary ** 2)) ** (1/2))
    def __str__(self):
        if self.imaginary == 0:
            result = "%.2f+0.00i" % (self.real)
        elif self.real == 0:
            if self.imaginary >= 0:
                result = "0.00+%.2fi" % (self.imaginary)
            else:
                result = "0.00-%.2fi" % (abs(self.imaginary))
        elif self.imaginary > 0:
            result = "%.2f+%.2fi" % (self.real, self.imaginary)
        else:
            result = "%.2f-%.2fi" % (self.real, abs(self.imaginary))
        return result

if __name__ == '__main__':
    c = map(float, input().split())
    d = map(float, input().split())
    x = Complex(*c)
    y = Complex(*d)
    print(*map(str, [x+y, x-y, x*y, x/y, x.mod(), y.mod()]), sep='\n')
# Out:
# 2 1
# 5 6
# 7.00+7.00i
# -3.00-5.00i
# 4.00+17.00i
# 0.26-0.11i
# 2.24+0.00i
# 7.81+0.00i
