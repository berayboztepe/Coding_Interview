# %% [markdown]
# ![resim_2021-04-05_175535.png](attachment:resim_2021-04-05_175535.png)

# %%
import re
for i in range(int(input())):
    try:
        s = input()
        re.compile(s)
    except:
        print(False)
        continue
    print(True)
# Out:
# 2
# .*/+
# True
# .*+
# False
