# %% [markdown]
# ![12.PNG](attachment:12.PNG)

# %% [markdown]
# ![resim_2021-04-01_205057.png](attachment:resim_2021-04-01_205057.png)

# %%
from cmath import phase
z = complex(input())
print(((z.real**2)+(z.imag**2))**(1/2))
print(phase(z))
# Out:
# 1+2j
# 2.23606797749979
# 1.1071487177940904
