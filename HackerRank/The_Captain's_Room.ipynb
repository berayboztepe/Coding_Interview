# %% [markdown]
# ![14.PNG](attachment:14.PNG)

# %% [markdown]
# ![resim_2021-04-03_201541.png](attachment:resim_2021-04-03_201541.png)

# %%
_, sums = int(input()), 0
room_numbers = list(map(int, input().split()))
A = set(room_numbers)

for i in A:
    sums += (i * _)
            

print((sums - sum(room_numbers)) // (_ - 1))
# Out:
# 5
# 1 2 3 6 5 4 4 2 5 3 6 1 6 5 3 2 4 1 2 5 1 4 3 6 8 4 3 1 5 6 2
# 8
