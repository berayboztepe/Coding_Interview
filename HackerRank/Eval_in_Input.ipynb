# %% [markdown]
# ![resim_2021-04-06_173836.png](attachment:resim_2021-04-06_173836.png)

# %%
n, k = map(int, input().split())

P = input().replace('x', str(n))

print(eval(P) == k)
# Out:
# 1 4
# x**3 + x**2 + x + 1
# True
