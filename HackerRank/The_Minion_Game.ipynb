# %% [markdown]
# ![8.PNG](attachment:8.PNG)

# %% [markdown]
# ![9.PNG](attachment:9.PNG)

# %% [markdown]
# ![resim_2021-03-31_224925.png](attachment:resim_2021-03-31_224925.png)

# %%
def minion_game(string):
    # your code goes here
    kev, stu, vowel, score1, score2 = {}, {}, 'AEIOU', 0, 0
    if not string.islower() == True:
        for i in range(len(string)):
            a = ''
            if string[i] in vowel:
                for j in range(i, len(string)):
                    a += string[j]
                    if not a in kev:
                        kev[a] = 1
                    else:
                        kev[a] += 1
            else:
                for j in range(i, len(string)):
                    a += string[j]
                    if not a in stu:
                        stu[a] = 1
                    else:
                        stu[a] += 1
    for i in kev.values(): score1 += i
    for i in stu.values(): score2 += i
    
    if score1 > score2: print('Kevin', score1)
    elif score1 == score2: print('Draw')
    else: print('Stuart', score2)
        
if __name__ == '__main__':
    s = input()
    minion_game(s)
# Out:
# BANANA
# Stuart 12

# %%
# without runtime error
def minion_game(string):
    # your code goes here
    vowel, K, S = 'AEIOU', 0, 0
    if not string.islower() == True:
        for i in range(len(string)):
            if string[i] in vowel:
                K += (len(s) - i)
            else:
                S += (len(s) - i)
    
    if K > S: print('Kevin', K)
    elif K == S: print('Draw')
    else: print('Stuart', S)
        
if __name__ == '__main__':
    s = input()
    minion_game(s)
# Out:
# BANANA
# Stuart 12
