# %% [markdown]
# ![resim_2021-04-06_190550.png](attachment:resim_2021-04-06_190550.png)

# %%
n, nums = int(input()), list(map(int, input().split()))
 
print(all(i > 0 for i in nums) and any(str(i) == str(i)[::-1] for i in nums))
# Out:
# 5
# 12 9 61 5 14
# True
