# %% [markdown]
# ![18.PNG](attachment:18.PNG)

# %% [markdown]
# ![resim_2021-04-03_225957.png](attachment:resim_2021-04-03_225957.png)

# %%
import calendar

date = input().split()

day = calendar.weekday(int(date[2]), int(date[0]), int(date[1]))

print(calendar.day_name[day].upper())
# Out:
# 08 05 2015
# WEDNESDAY
